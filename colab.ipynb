# %%
import os
# Create a temporary directory for runtime files
os.makedirs('/tmp/runtime-root', exist_ok=True)
os.chmod('/tmp/runtime-root', 0o700)
# Set the environment variable
os.environ['XDG_RUNTIME_DIR'] = '/tmp/runtime-root'
os.environ['RUST_LOG'] = 'debug'
os.environ['PATH'] += ":/root/.cargo/bin"

# !git clone http://www.github.com/syesildag/rust.git
# %cd rust
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
# !mkdir data
# %cd data
# !wget https://theweekinchess.com/assets/files/pgn/tatamast26.pgn
# %cd ..
# !apt install libvulkan-dev
# !source $HOME/.cargo/env
# !cargo run --release -p cli -- train --games data --batch 64 --epochs 1
